# %% [markdown]
# <a id='Top Doc'></a>

# %% [markdown]
# # P3: Wrangling OpenStreetMap Data
#
# ## Udacity Data Analyst NanoDegree
# ___

# %% [markdown]
# ### Contents
# ___
#
# 1. [Map Data](#Map-Data)
#
# 2. [Data Audit](#Data-Audit)
#
#  a. [Data Structure](#Data-Structure)
#
#  b. [Tag Attributes and Values](#Tag-Attributes-and-Values)
#
# [Data Cleaning](#Data-Cleaning)
#
# [References](#References)

# %% [markdown]
# ### Map Data
# ___
#
# ##### Los Angeles, California, USA
# [Mapzen](https://mapzen.com/data/metro-extracts/metro/los-angeles_california): `https://mapzen.com/data/metro-extracts/metro/los-angeles_california`
#
# I downloaded the initial los-angeles_california.osm dataset from Mapzen (not included in the repository). The original dataset is 8.6 GB large, and after trying to run some of the code from the courses locally, it crashed my computer. I proceeded to make a series of sample files to use (based off of the sample.py script given in the Project Details), which are described in this table:
#
# ##### Sample files used for Project
# Name | K-val | Size | Lines | Note
# ---|---:|---:|---:|---|
# *la-sample.osm* | 1,000 | 8.6 MB | 110,729 | This file was used to test early python data auditing and cleaning scripts.
# *la-med.osm* | 500 | 17.4 MB | 222,181 | Used as an intermediate test of the data auditing and cleaning scripts. Not included in this repository.
# *la-final.osm* | 150 | 58.0 MB | 741,172 | Final file used for auditing, cleaning, and importing into the MongoDB database. Not included in this repository, but can be added for resubmission if necessary.
#
# [Back To Contents](#Contents)

# %% [markdown]
# ### Data Audit
# ___
# #### Data Structure
#
# After reviewing the [OSM XML Content][1] page, I wanted to check that the sample dataset actually had the tags and structure as described. Mainly that the XML was organized as blocks of ***nodes*** with tags for each node, ***ways*** with tags and references to their respectives nodes, and ***relations*** with tags and references too.
#
# Using and modifying the `mapparser.py` code from the MongoDB Case Study for OSM Data, I generated a dictionary with element tag names, counts, and attributes. A simple table with the results can be seen here:
#
# [1]: #References

# %% [markdown]
# Name | Count | Attributes
# ---|---:|---
# member   | 78     | ref, role, type
# nd       | 41,121 | ref
# node     | 37,437 | changeset, id, lat, lon, timestamp, uid, user, version
# relation | 32     | changeset, id, timestamp, uid, user, version
# tag      | 24,813 | k, v
# way      | 3,655  | changeset, id, timestamp, uid, user, version

# %% [markdown]
# I further modified the `mapparser.py` to see the structure of the data. I named it `data_structure.py` and the results are here:

# %%
run data_structure.py
# Out:
# {'member': {'count': 78},
#  'nd': {'count': 41121},
#  'node': {'count': 37437,
#           'tag': {'attributes': {'k': 968, 'v': 968}, 'count': 968}},
#  'osm': {'count': 1,
#          'node': {'attributes': {'changeset': 37437,
#                                  'id': 37437,
#                                  'lat': 37437,
#                                  'lon': 37437,
#                                  'timestamp': 37437,
#                                  'uid': 37437,
#                                  'user': 37437,
#                                  'version': 37437},
#                   'count': 37437},
#          'relation': {'attributes': {'changeset': 32,
#                                      'id': 32,
#                                      'timestamp': 32,
#                                      'uid': 32,
#                                      'user': 32,
#                                      'version': 32},
#                       'count': 32},
#          'way': {'attributes': {'changeset': 3655,
#                                 'id': 3655,
#                                 'timestamp': 3655,
#                                 'uid': 3655,
#                                 'user': 3655,
#                                 'version': 3655},
#                  'count': 3655}},
#  'relation': {'count': 32,
#               'member': {'attributes': {'ref': 78, 'role': 78, 'type': 78},
#                          'count': 78},
#               'tag': {'attributes': {'k': 205, 'v': 205}, 'count': 205}},
#  'tag': {'count': 24813},
#  'way': {'count': 3655,
#          'nd': {'attributes': {'ref': 41121}, 'count': 41121},
#          'tag': {'attributes': {'k': 23640, 'v': 23640}, 'count': 23640}}}

# %% [markdown]
# Right away, you can see that ***nodes***, ***ways***, and ***members*** do in fact have the ***tag*** and ***nd*** tags as described by the OSM XML Content page. I also printed out the attributes, and nothing seems out of place. Further, the counts for each of the attributes matches the count of the tags themselves, so I don't have to worry about fixing any of those.
#
# Interestingly, there are some uncertainties mentioned some problems that could merit further investigation if the data cleaning and auditing functions were to be used as a service in any way. Of note are that id or usernames not necessarily being present, untagged unconnected nodes, element IDs that are negative, among others. It would be important to implement a solution to check and correct these problems.

# %% [markdown]
# #### Tag Attributes and Values
#
# The attributes for the tags member, nd, node, relation, and way seem to be fairly straightforward and easy to organize, so my Data Cleaning plan will organize those in a simple manner. However, the tag attributes may be a little more difficult to work with. Since the attribute ***k*** represents ***key***, which is assigned by the human user, there can be any number of different values for the k attribute.
#
# Again, I modified an example of the course code to make audit.py, which looks at the k values for tags of the given tag type. I ran it for both ***node*** and ***way*** tags, and found some interesting results. The lists were very long, so I will go over the issues that stand out below.
#
# ##### Node tags
# **addr:street** and **addr:street_direction_prefix** - these could be redundant, but I will have to review a few samples to see if this is worth correcting.

# %%
from audit import tag_search

# %%
results = tag_search("data/la-small.osm", "node", r'addr:street+')
#tag_k_search("data/la-small.osm", "tag", "tiger")
# Out:
# [{'k': 'tiger:cfcc', 'v': 'A74'},
#  {'k': 'tiger:tlid', 'v': '195710849:195710852'},
#  {'k': 'tiger:county', 'v': 'San Diego, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-5dac241b-d144-4c9c-9e26-b4dec4590a61'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'San Diego, CA'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92061'},
#  {'k': 'tiger:name_base', 'v': 'Sukat'},
#  {'k': 'tiger:name_type', 'v': 'Trl'},
#  {'k': 'tiger:zip_right', 'v': '92061'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '194813633'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-1be79c47-45e8-4ca4-8995-bc018e72ba7a'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '194723453:194723454'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-1be79c47-45e8-4ca4-8995-bc018e72ba7a'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '194723090:194722855:194722843'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-1be79c47-45e8-4ca4-8995-bc018e72ba7a'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '195097167:195097168:195097176:194838119'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '92882'},
#  {'k': 'tiger:name_base', 'v': 'Stetson'},
#  {'k': 'tiger:name_type', 'v': 'Cir'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92882'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '194863002:194880017'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92592'},
#  {'k': 'tiger:name_base', 'v': 'Calle Anita'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92592'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-1be79c47-45e8-4ca4-8995-bc018e72ba7a'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '194846174'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '92562'},
#  {'k': 'tiger:name_base', 'v': 'Cornhusk'},
#  {'k': 'tiger:name_type', 'v': 'Cir'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92562'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-1be79c47-45e8-4ca4-8995-bc018e72ba7a'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92509'},
#  {'k': 'tiger:name_base', 'v': 'Skylinks'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:zip_right', 'v': '92509'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144651748:144651749'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-793fb12a-827c-46ef-ab80-4a7bdd9a1fdb'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144599386'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-793fb12a-827c-46ef-ab80-4a7bdd9a1fdb'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:name_base', 'v': 'Dexter'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92501'},
#  {'k': 'tiger:zip_right', 'v': '92501'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '194808228:195084252'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92570'},
#  {'k': 'tiger:name_base', 'v': 'Rocky Hills'},
#  {'k': 'tiger:name_type', 'v': 'Rd'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92570'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '194811746'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92220'},
#  {'k': 'tiger:name_base', 'v': 'Ensign'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92220'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '145218157'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-793fb12a-827c-46ef-ab80-4a7bdd9a1fdb'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92545'},
#  {'k': 'tiger:name_base', 'v': 'La Paz'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:zip_right', 'v': '92545'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:zip_left', 'v': '92314'},
#  {'k': 'tiger:name_base', 'v': 'Shady'},
#  {'k': 'tiger:name_type', 'v': 'Ln'},
#  {'k': 'tiger:zip_right', 'v': '92314'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144965121'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '91786'},
#  {'k': 'tiger:name_base', 'v': 'Industry'},
#  {'k': 'tiger:name_type', 'v': 'Way'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '91786'},
#  {'k': 'tiger:name_direction_prefix', 'v': 'N'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '91762'},
#  {'k': 'tiger:name_base', 'v': 'Ralston'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:zip_right', 'v': '91762'},
#  {'k': 'tiger:name_direction_prefix', 'v': 'W'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144690708'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92337'},
#  {'k': 'tiger:name_base', 'v': 'Woodbridge'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92337'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144669377'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '91784'},
#  {'k': 'tiger:name_base', 'v': 'Darlene'},
#  {'k': 'tiger:name_type', 'v': 'Ct'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '91784'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '195050053:195050018:194686291'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92536'},
#  {'k': 'tiger:name_base', 'v': 'Leff'},
#  {'k': 'tiger:name_type', 'v': 'Rd'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92536'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '194820465'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92567'},
#  {'k': 'tiger:name_base', 'v': 'Cobblestone'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92567'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144661830'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92346'},
#  {'k': 'tiger:name_base', 'v': 'Vanda'},
#  {'k': 'tiger:name_type', 'v': 'Ln'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92346'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:name_base', 'v': '1st'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:zip_left', 'v': '92345'},
#  {'k': 'tiger:zip_right', 'v': '92345'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:zip_left', 'v': '92879'},
#  {'k': 'tiger:name_base', 'v': 'Gay'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:zip_right', 'v': '92879'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '194733940'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92501'},
#  {'k': 'tiger:name_base', 'v': 'Duluth'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92501'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '194778175'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '92879'},
#  {'k': 'tiger:name_base', 'v': '7th'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92879'},
#  {'k': 'tiger:name_direction_prefix', 'v': 'E'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:zip_left', 'v': '92220'},
#  {'k': 'tiger:name_base', 'v': 'Williams'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:zip_right', 'v': '92220'},
#  {'k': 'tiger:name_direction_prefix', 'v': 'W'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '194778787:194778788:194778797:194778799:194778803'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '92881'},
#  {'k': 'tiger:name_base', 'v': 'Jolora'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92881'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144708668:144991604'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '91701'},
#  {'k': 'tiger:name_base', 'v': 'Gateway'},
#  {'k': 'tiger:name_type', 'v': 'Rd'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '91701'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '194800957:195085444'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92505'},
#  {'k': 'tiger:name_base', 'v': 'Sunset Meadow'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92505'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '195067431:194751864'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:name_base', 'v': 'A'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '194830056:195080454:194800078:194800090'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92545'},
#  {'k': 'tiger:name_base', 'v': 'Augusta'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92545'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '194800868'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92501'},
#  {'k': 'tiger:name_base', 'v': 'Wabash'},
#  {'k': 'tiger:name_type', 'v': 'Ct'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92501'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92324'},
#  {'k': 'tiger:name_base', 'v': 'Alder'},
#  {'k': 'tiger:name_type', 'v': 'Ln'},
#  {'k': 'tiger:zip_right', 'v': '92324'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '195047494'},
#  {'k': 'tiger:county', 'v': 'Riverside, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '92220'},
#  {'k': 'tiger:name_base', 'v': 'Livingston'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92220'},
#  {'k': 'tiger:name_direction_prefix', 'v': 'S'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92356'},
#  {'k': 'tiger:name_base', 'v': 'Buchanan'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:zip_right', 'v': '92356'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144967447:144983983'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92336'},
#  {'k': 'tiger:name_base', 'v': 'San Jacinto'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92336'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:zip_left', 'v': '92392'},
#  {'k': 'tiger:name_base', 'v': 'Fremontia'},
#  {'k': 'tiger:name_type', 'v': 'Ln'},
#  {'k': 'tiger:zip_right', 'v': '92392'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144637731'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '91761'},
#  {'k': 'tiger:name_base', 'v': 'Ebony'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '91761'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144655936'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92404'},
#  {'k': 'tiger:name_base', 'v': 'Newport'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92404'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144745843:144745846:144746658'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '92394'},
#  {'k': 'tiger:name_base', 'v': 'Grand Mammoth'},
#  {'k': 'tiger:name_type', 'v': 'Pl'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92394'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:zip_left', 'v': '92345'},
#  {'k': 'tiger:name_base', 'v': 'Donert'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:zip_right', 'v': '92345'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '91709'},
#  {'k': 'tiger:name_base', 'v': 'Sage'},
#  {'k': 'tiger:name_type', 'v': 'Ln'},
#  {'k': 'tiger:zip_right', 'v': '91709'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144651893:144651894'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92410'},
#  {'k': 'tiger:name_base', 'v': 'Union'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92410'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144659792'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92408'},
#  {'k': 'tiger:name_base', 'v': 'George Webster'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92408'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144969184'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92337'},
#  {'k': 'tiger:name_base', 'v': 'Canterbury'},
#  {'k': 'tiger:name_type', 'v': 'Ct'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92337'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:name_base', 'v': 'Three Mountain Ranch'},
#  {'k': 'tiger:name_direction_prefix', 'v': 'E'},
#  {'k': 'tiger:name_type', 'v': 'Rd'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144700873'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '91701'},
#  {'k': 'tiger:name_base', 'v': 'Hudson'},
#  {'k': 'tiger:name_type', 'v': 'Ct'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '91701'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144991042:144991043'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '91701'},
#  {'k': 'tiger:name_base', 'v': 'Chesapeake'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '91701'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144737637:144737638'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92371'},
#  {'k': 'tiger:name_base', 'v': 'Chevoit'},
#  {'k': 'tiger:name_type', 'v': 'Rd'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92301'},
#  {'k': 'tiger:cfcc', 'v': 'A63'},
#  {'k': 'tiger:county', 'v': 'San Bernardino, CA'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '109986000:109986723'},
#  {'k': 'tiger:county', 'v': 'Ventura, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-7f3e6160-db61-48f6-8313-8097e4d32dcb'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '109989465'},
#  {'k': 'tiger:county', 'v': 'Ventura, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-7f3e6160-db61-48f6-8313-8097e4d32dcb'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '109986047:109986048'},
#  {'k': 'tiger:county', 'v': 'Ventura, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-7f3e6160-db61-48f6-8313-8097e4d32dcb'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '109993881'},
#  {'k': 'tiger:county', 'v': 'Ventura, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-7f3e6160-db61-48f6-8313-8097e4d32dcb'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '109959080:109959098'},
#  {'k': 'tiger:county', 'v': 'Ventura, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:name_base', 'v': 'San Jacinto'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '110072484:110072485:109981100:109981101'},
#  {'k': 'tiger:county', 'v': 'Ventura, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '91377'},
#  {'k': 'tiger:name_base', 'v': 'Medea Creek'},
#  {'k': 'tiger:name_type', 'v': 'Ln'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '91377'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '110002291:110002295'},
#  {'k': 'tiger:county', 'v': 'Ventura, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '93041'},
#  {'k': 'tiger:name_base', 'v': 'Seashore'},
#  {'k': 'tiger:name_type', 'v': 'Ct'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '93041'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '109954790:109954791'},
#  {'k': 'tiger:county', 'v': 'Ventura, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:name_base', 'v': 'Jamestown'},
#  {'k': 'tiger:name_type', 'v': 'Way'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-7f3e6160-db61-48f6-8313-8097e4d32dcb'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '109959798:110042441'},
#  {'k': 'tiger:county', 'v': 'Ventura, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '93010'},
#  {'k': 'tiger:name_base', 'v': 'Calle la Cumbre'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '93010'},
#  {'k': 'tiger:zip_left_1', 'v': '93010'},
#  {'k': 'tiger:zip_right_1', 'v': '93010'},
#  {'k': 'tiger:name_direction_prefix', 'v': 'N'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '109961411'},
#  {'k': 'tiger:county', 'v': 'Ventura, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '93012'},
#  {'k': 'tiger:name_base', 'v': 'Prairieview'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '93012'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Ventura, CA'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:name_base', 'v': 'Pennsylvania'},
#  {'k': 'tiger:name_type', 'v': 'Rd'},
#  {'k': 'tiger:cfcc', 'v': 'A74'},
#  {'k': 'tiger:tlid', 'v': '110089779'},
#  {'k': 'tiger:county', 'v': 'Ventura, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:name_base', 'v': 'Cherokee'},
#  {'k': 'tiger:name_type', 'v': 'Rd'},
#  {'k': 'tiger:cfcc', 'v': 'A41:A74'},
#  {'k': 'tiger:county', 'v': 'Ventura, CA'},
#  {'k': 'tiger:name_base', 'v': 'American'},
#  {'k': 'tiger:name_type', 'v': 'Rd:St'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '110081188'},
#  {'k': 'tiger:county', 'v': 'Ventura, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '93015'},
#  {'k': 'tiger:name_base', 'v': 'Deerfield'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '93015'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '110024348'},
#  {'k': 'tiger:county', 'v': 'Ventura, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '93063'},
#  {'k': 'tiger:name_base', 'v': 'Oldenberg'},
#  {'k': 'tiger:name_type', 'v': 'Way'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '93063'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-7f3e6160-db61-48f6-8313-8097e4d32dcb'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '109967280:110018366:110080750:110080751'},
#  {'k': 'tiger:county', 'v': 'Ventura, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '91360'},
#  {'k': 'tiger:name_base', 'v': 'Campus'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '91360'},
#  {'k': 'tiger:name_direction_prefix', 'v': 'S'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '110106528'},
#  {'k': 'tiger:county', 'v': 'Ventura, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:name_base', 'v': 'Hidden Ranch'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Los Angeles, CA'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:cfcc', 'v': 'A63'},
#  {'k': 'tiger:county', 'v': 'Los Angeles, CA'},
#  {'k': 'tiger:cfcc', 'v': 'A74'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '141550859'},
#  {'k': 'tiger:county', 'v': 'Los Angeles, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '91331'},
#  {'k': 'tiger:name_base', 'v': 'Judd'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '91331'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '141572308:141572292'},
#  {'k': 'tiger:county', 'v': 'Los Angeles, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '90048'},
#  {'k': 'tiger:name_base', 'v': 'Swall'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '90048'},
#  {'k': 'tiger:name_direction_prefix', 'v': 'N'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:zip_left', 'v': '92821'},
#  {'k': 'tiger:name_base', 'v': 'Elm'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:zip_right', 'v': '92821'},
#  {'k': 'tiger:name_direction_prefix', 'v': 'E'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144125055:144125056:144125071'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '92869'},
#  {'k': 'tiger:name_base', 'v': 'Mulberry'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92869'},
#  {'k': 'tiger:name_direction_prefix', 'v': 'S'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '141544681'},
#  {'k': 'tiger:county', 'v': 'Los Angeles, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '91343'},
#  {'k': 'tiger:name_base', 'v': 'Frankirst'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '91343'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Los Angeles, CA'},
#  {'k': 'tiger:zip_left', 'v': '91024'},
#  {'k': 'tiger:name_base', 'v': 'Monte Vista'},
#  {'k': 'tiger:name_type', 'v': 'Ln'},
#  {'k': 'tiger:zip_right', 'v': '91024'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:name_base', 'v': 'Sweetpea'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid',
#   'v': '144408800:144408801:144408836:144408837:144090333:144071564:144404849:144107115:144071534:144071537:144071549:144417860:144088253:144109562:144410301:144417807:144109563:144106823:144070048:144070051:144070057:144069906:144088062:144088064:144106870:14406'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92677'},
#  {'k': 'tiger:name_base', 'v': 'Niguel'},
#  {'k': 'tiger:name_type', 'v': 'Rd'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92677'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid',
#   'v': '144013133:144013131:144013135:144013137:144013143:144013147'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:name_base', 'v': 'Broadway'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-96b38365-dd2d-4eab-8ec1-33441607e7c5'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid',
#   'v': '141584605:141584608:141584590:141584537:141584541:141584544:141584592'},
#  {'k': 'tiger:county', 'v': 'Los Angeles, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '90277'},
#  {'k': 'tiger:name_base', 'v': 'Via Los Miradores'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '90277'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-e7a65206-5b4e-4f1c-be5b-f07c49e73831'},
#  {'k': 'tiger:cfcc', 'v': 'A74'},
#  {'k': 'tiger:tlid', 'v': '144105282'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92677'},
#  {'k': 'tiger:name_base', 'v': 'Misty Sea'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:zip_right', 'v': '92677'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144045831'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92626'},
#  {'k': 'tiger:name_base', 'v': 'Cassia'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92626'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144116637'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '90630'},
#  {'k': 'tiger:name_base', 'v': 'Midway'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '90630'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:zip_left', 'v': '92614'},
#  {'k': 'tiger:name_base', 'v': 'Bayporte'},
#  {'k': 'tiger:zip_right', 'v': '92614'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:zip_left', 'v': '92870'},
#  {'k': 'tiger:name_base', 'v': 'Harte'},
#  {'k': 'tiger:name_type', 'v': 'Way'},
#  {'k': 'tiger:zip_right', 'v': '92870'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144012716'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '90740'},
#  {'k': 'tiger:name_base', 'v': '8th'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '90740'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '141752943:141752949'},
#  {'k': 'tiger:county', 'v': 'Los Angeles, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '90603'},
#  {'k': 'tiger:name_base', 'v': 'Raywood'},
#  {'k': 'tiger:name_type', 'v': 'Ln'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '90603'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:zip_left', 'v': '92646'},
#  {'k': 'tiger:name_base', 'v': 'Groton'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:zip_right', 'v': '92646'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:zip_left', 'v': '92886'},
#  {'k': 'tiger:name_base', 'v': 'Niantic'},
#  {'k': 'tiger:name_type', 'v': 'Pl'},
#  {'k': 'tiger:zip_right', 'v': '92886'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:name_base', 'v': 'Charreadas'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:zip_left', 'v': '92706'},
#  {'k': 'tiger:name_base', 'v': 'Buffalo'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:zip_right', 'v': '92706'},
#  {'k': 'tiger:name_direction_prefix', 'v': 'W'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '141555695:141555697'},
#  {'k': 'tiger:county', 'v': 'Los Angeles, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '91406'},
#  {'k': 'tiger:name_base', 'v': 'Aldea'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '91406'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:name_base', 'v': 'Irvine Haul'},
#  {'k': 'tiger:name_type', 'v': 'Rd'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144065312:144065314'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92691'},
#  {'k': 'tiger:name_base', 'v': 'Arcada'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92691'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144064635'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92653'},
#  {'k': 'tiger:name_base', 'v': 'Vespucci'},
#  {'k': 'tiger:name_type', 'v': 'Rd'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92653'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '141818478'},
#  {'k': 'tiger:county', 'v': 'Los Angeles, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '90275'},
#  {'k': 'tiger:name_base', 'v': 'Rolling Ridge'},
#  {'k': 'tiger:name_type', 'v': 'Rd'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '90275'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144120636'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92677'},
#  {'k': 'tiger:name_base', 'v': 'Rancho de Linda'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92677'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-96b38365-dd2d-4eab-8ec1-33441607e7c5'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144051077:144051089:144051090:144051092'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '92868'},
#  {'k': 'tiger:name_base', 'v': 'Palmyra'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92868'},
#  {'k': 'tiger:name_direction_prefix', 'v': 'W'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:name_base', 'v': 'Waverly'},
#  {'k': 'tiger:name_base_1', 'v': 'Waverly'},
#  {'k': 'tiger:name_direction_prefix_1', 'v': 'S'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:name_type_1', 'v': 'Dr'},
#  {'k': 'tiger:zip_left', 'v': '92840'},
#  {'k': 'tiger:zip_right', 'v': '92840'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '141757672'},
#  {'k': 'tiger:county', 'v': 'Los Angeles, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '91748'},
#  {'k': 'tiger:name_base', 'v': 'Radby'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '91748'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144019237'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '92708'},
#  {'k': 'tiger:name_base', 'v': 'McBride River'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92708'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '141621318:141621319:141621321:141621322'},
#  {'k': 'tiger:county', 'v': 'Los Angeles, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '90011'},
#  {'k': 'tiger:name_base', 'v': 'Morgan'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '90011'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '141749180'},
#  {'k': 'tiger:county', 'v': 'Los Angeles, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '90650'},
#  {'k': 'tiger:name_base', 'v': 'Ben Nevis'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '90650'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:name_base', 'v': 'Calas'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '141816583:141533257'},
#  {'k': 'tiger:county', 'v': 'Los Angeles, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '91304'},
#  {'k': 'tiger:name_base', 'v': 'Glassport'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '91304'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:name_base', 'v': 'Sunset'},
#  {'k': 'tiger:name_type', 'v': 'Way'},
#  {'k': 'tiger:name_direction_suffix', 'v': 'E'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144002681:144002625'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '90720'},
#  {'k': 'tiger:name_base', 'v': 'Salmon'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '90720'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:zip_left', 'v': '92705'},
#  {'k': 'tiger:name_base', 'v': 'Franzen'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:zip_right', 'v': '92705'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144000198'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '90720'},
#  {'k': 'tiger:name_base', 'v': 'Kearsarge'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '90720'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144029030:144029032:144029034'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '92868'},
#  {'k': 'tiger:name_base', 'v': 'Cherry'},
#  {'k': 'tiger:name_type', 'v': 'Dr'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92868'},
#  {'k': 'tiger:name_direction_prefix', 'v': 'W'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144070564:144070480'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92653'},
#  {'k': 'tiger:name_base', 'v': 'San Pedro'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92653'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92691'},
#  {'k': 'tiger:name_base', 'v': 'Demasia'},
#  {'k': 'tiger:zip_right', 'v': '92691'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144060803'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92807'},
#  {'k': 'tiger:name_base', 'v': 'Paseo Murillo'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92807'},
#  {'k': 'tiger:upload_uuid',
#   'v': 'bulk_upload.pl-96b38365-dd2d-4eab-8ec1-33441607e7c5'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144043067'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92704'},
#  {'k': 'tiger:name_base', 'v': 'Manly'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92704'},
#  {'k': 'tiger:name_direction_prefix', 'v': 'W'},
#  {'k': 'tiger:county', 'v': 'Los Angeles, CA'},
#  {'k': 'tiger:zip_left', 'v': '90247'},
#  {'k': 'tiger:zip_right', 'v': '90247'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144381697'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92656'},
#  {'k': 'tiger:name_base', 'v': 'Headland'},
#  {'k': 'tiger:name_type', 'v': 'Pl'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92656'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '141705095'},
#  {'k': 'tiger:county', 'v': 'Los Angeles, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '93543'},
#  {'k': 'tiger:name_base', 'v': '117th'},
#  {'k': 'tiger:name_type', 'v': 'St'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '93543'},
#  {'k': 'tiger:name_direction_suffix', 'v': 'E'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:name_base', 'v': 'Harvard'},
#  {'k': 'tiger:name_type', 'v': 'Ave'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:reviewed', 'v': 'no'},
#  {'k': 'tiger:zip_left', 'v': '92673'},
#  {'k': 'tiger:name_base', 'v': 'Calle Corral'},
#  {'k': 'tiger:zip_right', 'v': '92673'},
#  {'k': 'tiger:cfcc', 'v': 'A41'},
#  {'k': 'tiger:tlid', 'v': '144057905'},
#  {'k': 'tiger:county', 'v': 'Orange, CA'},
#  {'k': 'tiger:source', 'v': 'tiger_import_dch_v0.6_20070809'},
#  {'k': 'tiger:zip_left', 'v': '92604'},
#  {'k': 'tiger:name_base', 'v': 'Eccelstone'},
#  {'k': 'tiger:name_type', 'v': 'Cir'},
#  {'k': 'tiger:separated', 'v': 'no'},
#  {'k': 'tiger:zip_right', 'v': '92604'},
#  ...]

# %% [markdown]
# ### Data Cleaning
# ___
#
#
# [Back To Contents](#Contents)

# %% [markdown]
# ### References
# ___
#
# 1. [OSM XML Contents](https://wiki.openstreetmap.org/wiki/OSM_XML#Contents): `https://wiki.openstreetmap.org/wiki/OSM_XML#Contents`
#
# ___
# [Back To Contents](#Contents)
